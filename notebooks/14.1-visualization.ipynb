# %%
# !conda install -c conda-forge matplotlib scikit-learn -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# doneecting package metadata (repodata.json): -
# doneing environment: \
#
# # All requested packages already installed.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression

# %%
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
feature = "sepal length (cm)" # by defining this, it allows you to type in the whole title a lot less
gb = iris_df.groupby("species")
# Create a dictionary mapping species IDs to color names, which we will access inside the for loop
cdict = {'setosa':'tomato',
         'versicolor':'orange',
         'virginica':'darkseagreen'}
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.4, color=cdict[sp])
plt.legend()
plt.title(f'Histogram of {feature} by Species')
plt.ylabel('Count')
plt.xlabel('Sepal Length (cm)')
plt.savefig('sepal_length.png')
# Out:
# /var/folders/c9/q4xsmgsx3kq4qxd12hbwrstw0000gn/T/ipykernel_18613/4059017537.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
feature = "sepal width (cm)" # because this variable was defined, we can copy and paste this code and change just the word "width" 
                             # to now plot the same histogram but with a different variable, instead of having to change the whole code
gb = iris_df.groupby("species")
# Create a dictionary mapping species IDs to color names, which we will access inside the for loop
cdict = {'setosa':'tomato',
         'versicolor':'orange',
         'virginica':'darkseagreen'}
for sp, dat in gb:
    plt.hist(dat[feature], label=sp, alpha=0.5, color=cdict[sp])
plt.legend()
plt.title(f'Histogram of {feature} by Species')
plt.ylabel('Count')
plt.xlabel(feature)
# Out:
# /var/folders/c9/q4xsmgsx3kq4qxd12hbwrstw0000gn/T/ipykernel_18613/3134746367.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")
# Text(0.5, 0, 'sepal width (cm)')

# %%
print(iris_df.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
x_feature = "sepal length (cm)"
y_feature = "sepal width (cm)"

gb = iris_df.groupby("species")
cdict = {'setosa':'tomato',
         'versicolor':'orange',
         'virginica':'darkseagreen'}
for sp, dat in gb:
    plt.scatter(dat[x_feature], dat[y_feature], label=sp, alpha=0.75, color=cdict[sp], marker='D')

plt.title(f'Histogram of {feature} by Species')
plt.ylabel('Count')
plt.xlabel('Sepal Length (cm)')
plt.legend()
plt.savefig('sepal_length.png')
# Out:
# /var/folders/c9/q4xsmgsx3kq4qxd12hbwrstw0000gn/T/ipykernel_18613/2594317575.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = iris_df.groupby("species")

# %%
iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.5,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);
